# %%
# Parse full course data

import requests
import json
from pprint import pprint

base_url = 'https://sandbox.api.it.nyu.edu/class-roster-exp/classes'
headers = {'Content-Type': 'application/json', 'Authorization': 'Bearer 357e6f16-2086-3d75-875d-57ff26ca98f7' }

int_max = 2**32 - 1
r = requests.get(base_url + '?limit=37000', headers=headers)
datas = json.loads(r.content)
print(len(datas))
# Out:
# 33720

# %%
pprint(datas[:10])
# Out:
# [{'academic_career': 'UGRD',
#   'building_code': 'JABS',
#   'building_description': 'Tandon, Jacobs Academic Bldg',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'O',
#   'class_number': 15584,
#   'class_section': 'B4RC',
#   'class_type': 'RCT',
#   'class_type_description': 'Recitation',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 19,
#   'facility_id': 'JABS_775',
#   'instructor_name': 'Pollack,Myron I.',
#   'instructor_nyu_id': 'N13009881',
#   'instructor_preferred_name': 'Pollack,Myron',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '775',
#   'room_cap_request': 20,
#   'room_descr': 'Jacobs Academic Bldg Rm 775',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'JABS',
#   'building_description': 'Tandon, Jacobs Academic Bldg',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'O',
#   'class_number': 15585,
#   'class_section': 'B4LB',
#   'class_type': 'LAB',
#   'class_type_description': 'Laboratory',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 19,
#   'facility_id': 'JABS_878',
#   'instructor_name': 'Pollack,Myron I.',
#   'instructor_nyu_id': 'N13009881',
#   'instructor_preferred_name': 'Pollack,Myron',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '878',
#   'room_cap_request': 20,
#   'room_descr': 'Jacobs Academic Bldg Rm 878',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'RGSH',
#   'building_description': 'Tandon, Rogers Hall',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'C',
#   'class_number': 15701,
#   'class_section': 'D1RC',
#   'class_type': 'RCT',
#   'class_type_description': 'Recitation',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 20,
#   'facility_id': 'RGSH_708',
#   'instructor_name': 'Aber,Janice E.',
#   'instructor_nyu_id': 'N14865102',
#   'instructor_preferred_name': 'Aber,Janice E',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '708',
#   'room_cap_request': 20,
#   'room_descr': 'Rogers Hall, Rm 708',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'JABS',
#   'building_description': 'Tandon, Jacobs Academic Bldg',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'C',
#   'class_number': 15702,
#   'class_section': 'D1LB',
#   'class_type': 'LAB',
#   'class_type_description': 'Laboratory',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 20,
#   'facility_id': 'JABS_878',
#   'instructor_name': 'Aber,Janice E.',
#   'instructor_nyu_id': 'N14865102',
#   'instructor_preferred_name': 'Aber,Janice E',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '878',
#   'room_cap_request': 20,
#   'room_descr': 'Jacobs Academic Bldg Rm 878',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'DIBN',
#   'building_description': 'Tandon, Dibner Building',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'O',
#   'class_number': 15703,
#   'class_section': 'DLEC',
#   'class_type': 'LEC',
#   'class_type_description': 'Lecture',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 140,
#   'enrollment_total': 137,
#   'facility_id': 'DIBN_AUD',
#   'instructor_name': 'Robinson-Surry,Julia M',
#   'instructor_nyu_id': 'N12794877',
#   'instructor_preferred_name': 'Robinson-Surry,Julia M',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': 'AUD',
#   'room_cap_request': 140,
#   'room_descr': 'Dibner , Pfizer Auditorium',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'RGSH',
#   'building_description': 'Tandon, Rogers Hall',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'O',
#   'class_number': 15704,
#   'class_section': 'D3RC',
#   'class_type': 'RCT',
#   'class_type_description': 'Recitation',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 19,
#   'facility_id': 'RGSH_203',
#   'instructor_name': 'Aber,Janice E.',
#   'instructor_nyu_id': 'N14865102',
#   'instructor_preferred_name': 'Aber,Janice E',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '203',
#   'room_cap_request': 20,
#   'room_descr': 'Rogers Hall, Rm 203',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'JABS',
#   'building_description': 'Tandon, Jacobs Academic Bldg',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'O',
#   'class_number': 15705,
#   'class_section': 'D3LB',
#   'class_type': 'LAB',
#   'class_type_description': 'Laboratory',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 19,
#   'facility_id': 'JABS_878',
#   'instructor_name': 'Aber,Janice E.',
#   'instructor_nyu_id': 'N14865102',
#   'instructor_preferred_name': 'Aber,Janice E',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '878',
#   'room_cap_request': 20,
#   'room_descr': 'Jacobs Academic Bldg Rm 878',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'JABS',
#   'building_description': 'Tandon, Jacobs Academic Bldg',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'C',
#   'class_number': 15813,
#   'class_section': 'D4LB',
#   'class_type': 'LAB',
#   'class_type_description': 'Laboratory',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 20,
#   'facility_id': 'JABS_878',
#   'instructor_name': 'Hagver,Rena',
#   'instructor_nyu_id': 'N16742520',
#   'instructor_preferred_name': 'Hagver,Rena',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '878',
#   'room_cap_request': 20,
#   'room_descr': 'Jacobs Academic Bldg Rm 878',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'RGSH',
#   'building_description': 'Tandon, Rogers Hall',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'C',
#   'class_number': 15814,
#   'class_section': 'D4RC',
#   'class_type': 'RCT',
#   'class_type_description': 'Recitation',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 20,
#   'facility_id': 'RGSH_203',
#   'instructor_name': 'Hagver,Rena',
#   'instructor_nyu_id': 'N16742520',
#   'instructor_preferred_name': 'Hagver,Rena',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '203',
#   'room_cap_request': 20,
#   'room_descr': 'Rogers Hall, Rm 203',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4},
#  {'academic_career': 'UGRD',
#   'building_code': 'RGSH',
#   'building_description': 'Tandon, Rogers Hall',
#   'catalog_number': '1004',
#   'class_enrollment_status': 'C',
#   'class_number': 15915,
#   'class_section': 'B3RC',
#   'class_type': 'RCT',
#   'class_type_description': 'Recitation',
#   'combined_section': ' ',
#   'course_id': '072227',
#   'course_title': 'General Chemistry for Engineers',
#   'enrollment_cap': 20,
#   'enrollment_total': 20,
#   'facility_id': 'RGSH_317',
#   'instructor_name': 'Roy,Debasish',
#   'instructor_nyu_id': 'N10315710',
#   'instructor_preferred_name': 'Roy,Debasish',
#   'instructor_role': 'PI',
#   'instructor_role_description': 'Primary Instructor',
#   'location': 'BRKLN',
#   'location_description': 'Brooklyn Campus',
#   'nyu_course_id': 'CM-UY1004',
#   'room': '317',
#   'room_cap_request': 20,
#   'room_descr': 'Rogers Hall, Rm 317',
#   'subject_code': 'CM-UY',
#   'term': '1168',
#   'term_description': 'Fall 2016',
#   'units_max': 4,
#   'units_min': 4}]

# %%
# Save the json file
with open('full_courses.json', 'w') as outfile:
    json.dump(datas, outfile)

# %%
# Parse course description
base_url = 'https://sandbox.api.it.nyu.edu/course-catalog-exp/courses'
headers = {'Content-Type': 'application/json', 'Authorization': 'Bearer 357e6f16-2086-3d75-875d-57ff26ca98f7' }

int_max = 2**32 - 1
r = requests.get(base_url + '?limit=25000', headers=headers)
datas = json.loads(r.content)
print(len(datas))

# %%
# Save the json file
with open('courses.json', 'w') as outfile:
    json.dump(datas, outfile)
