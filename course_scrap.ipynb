# %%
# Parse full course data

import requests
import json
from pprint import pprint

base_url = 'https://sandbox.api.it.nyu.edu/class-roster-exp/classes'
headers = {'Content-Type': 'application/json', 'Authorization': 'Bearer 357e6f16-2086-3d75-875d-57ff26ca98f7' }

int_max = 2**32 - 1
r = requests.get(base_url + '?limit=37000', headers=headers)
datas = json.loads(r.content)
print(len(datas))
# Out:
# 33720

# %%
pprint(datas[:10])
# Out:
# [{u'academic_career': u'UGRD',
#   u'building_code': u'JABS',
#   u'building_description': u'Tandon, Jacobs Academic Bldg',
#   u'catalog_number': u'1004',
#   u'class_enrollment_status': u'O',
#   u'class_number': 15584,
#   u'class_section': u'B4RC',
#   u'class_type': u'RCT',
#   u'class_type_description': u'Recitation',
#   u'combined_section': u' ',
#   u'course_id': u'072227',
#   u'course_title': u'General Chemistry for Engineers',
#   u'enrollment_cap': 20,
#   u'enrollment_total': 19,
#   u'facility_id': u'JABS_775',
#   u'instructor_name': u'Pollack,Myron I.',
#   u'instructor_nyu_id': u'N13009881',
#   u'instructor_preferred_name': u'Pollack,Myron',
#   u'instructor_role': u'PI',
#   u'instructor_role_description': u'Primary Instructor',
#   u'location': u'BRKLN',
#   u'location_description': u'Brooklyn Campus',
#   u'nyu_course_id': u'CM-UY1004',
#   u'room': u'775',
#   u'room_cap_request': 20,
#   u'room_descr': u'Jacobs Academic Bldg Rm 775',
# ...

# %%
# Save the json file
with open('full_courses.json', 'w') as outfile:
    json.dump(datas, outfile)

# %%
# Parse course description
base_url = 'https://sandbox.api.it.nyu.edu/course-catalog-exp/courses'
headers = {'Content-Type': 'application/json', 'Authorization': 'Bearer 357e6f16-2086-3d75-875d-57ff26ca98f7' }

int_max = 2**32 - 1
r = requests.get(base_url + '?limit=25000', headers=headers)
datas = json.loads(r.content)
print(len(datas))

# %%
# Save the json file
with open('courses.json', 'w') as outfile:
    json.dump(datas, outfile)
